# %% [markdown]
# Modules's Importation

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Loading data

# %%
ecgdata = r'C:\Users\Helies\Desktop\M2\S9\Santé AP\CM1_MOTTET_Denis\HAH913E-2024-ECG_001\data\ECGu.txt'
data = np.loadtxt(ecgdata)

# %% [markdown]
# Ploting

# %%
plt.plot(data[:,1])
plt.axhline(y=775, color='r', linestyle='-')
plt.axhline(y=388, color='r', linestyle='-')
# plt.xlim(0,4000)

plt.xlabel('Time (s)')
plt.ylabel('Lead I ($\mu$V)')
plt.grid(color ='grey', linestyle='--')
